# %%
try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

if IN_COLAB:
  print("We're running Colab")
# Out:
# We're running Colab

# %%
import tensorflow as tf

print("Running TensorFlow version ",tf.__version__)

# Parse tensorflow version
import re

version_match = re.match("([0-9]+)\.([0-9]+)", tf.__version__)
tf_major, tf_minor = int(version_match.group(1)) , int(version_match.group(2))
print("Version {v:d}, minor {m:d}".format(v=tf_major, m=tf_minor) )
# Out:
# Running TensorFlow version  2.15.0
# Version 2, minor 15

# %% [markdown]
# Derived from
#
# Keras blog: https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html

# %% [markdown]
# Mount my Google Drive (have data stored there)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# # Download the Cats and Dogs dataset
#
# - The raw dataset comes from [Kaggle](https://www.kaggle.com/c/dogs-vs-cats/data) and is quite a large archive file.  We only need one file
#   - train.zip
#
# - A **subset** of the training data was created, and organized as described [here](https://gist.github.com/fchollet/7eb39b44eb9e16e59632d25fb3119975)
#   - Only 1000 training examples, 400 validation examples, per animal type
#   - The notebook "Dogs_and_Cats_reformat" will perform this reformatting
# - The reformatted, subset of the dataset (much smaller) was placed in an archive, which is read in this step

# %% [markdown]
# Unzip the Cats and Dogs images into pwd (i.e., /content).  That is where the code is looking

# %%
import os
# !pwd

data_dir="data"
os.makedirs(data_dir, exist_ok=True)


if not (os.path.isdir("train") and os.path.isdir("validation") ):
  # %cd $data_dir
  # !tar -zxvf '/content/gdrive/My Drive/data/cats_and_dogs/cats_v_dogs.tgz'
  # %cd ..
# Out:
# /content
# /content/data
# ./
# ./validation/
# ./validation/dogs/
# ./validation/dogs/dog.1302.jpg
# ./validation/dogs/dog.1242.jpg
# ./validation/dogs/dog.1108.jpg
# ./validation/dogs/dog.1088.jpg
# ./validation/dogs/dog.1140.jpg
# ./validation/dogs/dog.1357.jpg
# ./validation/dogs/dog.1194.jpg
# ./validation/dogs/dog.1162.jpg
# ./validation/dogs/dog.1219.jpg
# ./validation/dogs/dog.1142.jpg
# ./validation/dogs/dog.1005.jpg
# ./validation/dogs/dog.1138.jpg
# ./validation/dogs/dog.1293.jpg
# ./validation/dogs/dog.1382.jpg
# ./validation/dogs/dog.1331.jpg
# ./validation/dogs/dog.1389.jpg
# ./validation/dogs/dog.1154.jpg
# ./validation/dogs/dog.1375.jpg
# ./validation/dogs/dog.1352.jpg
# ./validation/dogs/dog.1244.jpg
# ./validation/dogs/dog.1325.jpg
# ./validation/dogs/dog.1329.jpg
# ./validation/dogs/dog.1322.jpg
# ./validation/dogs/dog.1304.jpg
# ./validation/dogs/dog.1183.jpg
# ./validation/dogs/dog.1363.jpg
# ./validation/dogs/dog.1393.jpg
# ./validation/dogs/dog.1012.jpg
# ./validation/dogs/dog.1240.jpg
# ./validation/dogs/dog.1009.jpg
# ./validation/dogs/dog.1157.jpg
# ./validation/dogs/dog.1062.jpg
# ./validation/dogs/dog.1312.jpg
# ./validation/dogs/dog.1035.jpg
# ./validation/dogs/dog.1301.jpg
# ./validation/dogs/dog.1337.jpg
# ./validation/dogs/dog.1118.jpg
# ./validation/dogs/dog.1251.jpg
# ./validation/dogs/dog.1265.jpg
# ./validation/dogs/dog.1368.jpg
# ./validation/dogs/dog.1247.jpg
# ./validation/dogs/dog.1233.jpg
# ./validation/dogs/dog.1155.jpg
# ./validation/dogs/dog.1109.jpg
# ./validation/dogs/dog.1223.jpg
# ./validation/dogs/dog.1222.jpg
# ./validation/dogs/dog.1093.jpg
# ./validation/dogs/dog.1373.jpg
# ./validation/dogs/dog.1158.jpg
# ./validation/dogs/dog.1150.jpg
# ./validation/dogs/dog.1054.jpg
# ./validation/dogs/dog.1216.jpg
# ./validation/dogs/dog.1029.jpg
# ./validation/dogs/dog.1334.jpg
# ./validation/dogs/dog.1152.jpg
# ./validation/dogs/dog.1370.jpg
# ./validation/dogs/dog.1336.jpg
# ./validation/dogs/dog.1034.jpg
# ./validation/dogs/dog.1317.jpg
# ./validation/dogs/dog.1381.jpg
# ./validation/dogs/dog.1192.jpg
# ./validation/dogs/dog.1298.jpg
# ./validation/dogs/dog.1046.jpg
# ./validation/dogs/dog.1399.jpg
# ./validation/dogs/dog.1041.jpg
# ./validation/dogs/dog.1348.jpg
# ./validation/dogs/dog.1214.jpg
# ./validation/dogs/dog.1395.jpg
# ./validation/dogs/dog.1237.jpg
# ./validation/dogs/dog.1013.jpg
# ./validation/dogs/dog.1234.jpg
# ./validation/dogs/dog.1291.jpg
# ./validation/dogs/dog.1174.jpg
# ./validation/dogs/dog.1292.jpg
# ./validation/dogs/dog.1351.jpg
# ./validation/dogs/dog.1354.jpg
# ./validation/dogs/dog.1068.jpg
# ./validation/dogs/dog.1165.jpg
# ./validation/dogs/dog.1392.jpg
# ./validation/dogs/dog.1285.jpg
# ./validation/dogs/dog.1290.jpg
# ./validation/dogs/dog.1316.jpg
# ./validation/dogs/dog.1230.jpg
# ./validation/dogs/dog.1052.jpg
# ./validation/dogs/dog.1127.jpg
# ./validation/dogs/dog.1245.jpg
# ./validation/dogs/dog.1019.jpg
# ./validation/dogs/dog.1197.jpg
# ./validation/dogs/dog.1043.jpg
# ./validation/dogs/dog.1202.jpg
# ./validation/dogs/dog.1366.jpg
# ./validation/dogs/dog.1055.jpg
# ./validation/dogs/dog.1008.jpg
# ./validation/dogs/dog.1099.jpg
# ./validation/dogs/dog.1051.jpg
# ./validation/dogs/dog.1207.jpg
# ./validation/dogs/dog.1319.jpg
# ./validation/dogs/dog.1374.jpg
# ./validation/dogs/dog.1296.jpg
# ./validation/dogs/dog.1180.jpg
# ./validation/dogs/dog.1367.jpg
# ./validation/dogs/dog.1168.jpg
# ./validation/dogs/dog.1276.jpg
# ./validation/dogs/dog.1156.jpg
# ./validation/dogs/dog.1105.jpg
# ./validation/dogs/dog.1177.jpg
# ./validation/dogs/dog.1122.jpg
# ./validation/dogs/dog.1271.jpg
# ./validation/dogs/dog.1310.jpg
# ./validation/dogs/dog.1136.jpg
# ./validation/dogs/dog.1107.jpg
# ./validation/dogs/dog.1006.jpg
# ./validation/dogs/dog.1284.jpg
# ./validation/dogs/dog.1191.jpg
# ./validation/dogs/dog.1056.jpg
# ./validation/dogs/dog.1264.jpg
# ./validation/dogs/dog.1121.jpg
# ./validation/dogs/dog.1061.jpg
# ./validation/dogs/dog.1394.jpg
# ./validation/dogs/dog.1023.jpg
# ./validation/dogs/dog.1383.jpg
# ./validation/dogs/dog.1204.jpg
# ./validation/dogs/dog.1135.jpg
# ./validation/dogs/dog.1272.jpg
# ./validation/dogs/dog.1397.jpg
# ./validation/dogs/dog.1313.jpg
# ./validation/dogs/dog.1297.jpg
# ./validation/dogs/dog.1016.jpg
# ./validation/dogs/dog.1081.jpg
# ./validation/dogs/dog.1090.jpg
# ./validation/dogs/dog.1209.jpg
# ./validation/dogs/dog.1057.jpg
# ./validation/dogs/dog.1269.jpg
# ./validation/dogs/dog.1060.jpg
# ./validation/dogs/dog.1011.jpg
# ./validation/dogs/dog.1306.jpg
# ./validation/dogs/dog.1210.jpg
# ./validation/dogs/dog.1089.jpg
# ./validation/dogs/dog.1196.jpg
# ./validation/dogs/dog.1281.jpg
# ./validation/dogs/dog.1243.jpg
# ./validation/dogs/dog.1198.jpg
# ./validation/dogs/dog.1299.jpg
# ./validation/dogs/dog.1042.jpg
# ./validation/dogs/dog.1345.jpg
# ./validation/dogs/dog.1226.jpg
# ./validation/dogs/dog.1356.jpg
# ./validation/dogs/dog.1323.jpg
# ./validation/dogs/dog.1225.jpg
# ./validation/dogs/dog.1149.jpg
# ./validation/dogs/dog.1059.jpg
# ./validation/dogs/dog.1007.jpg
# ./validation/dogs/dog.1254.jpg
# ./validation/dogs/dog.1074.jpg
# ./validation/dogs/dog.1030.jpg
# ./validation/dogs/dog.1144.jpg
# ./validation/dogs/dog.1288.jpg
# ./validation/dogs/dog.1305.jpg
# ./validation/dogs/dog.1070.jpg
# ./validation/dogs/dog.1044.jpg
# ./validation/dogs/dog.1092.jpg
# ./validation/dogs/dog.1321.jpg
# ./validation/dogs/dog.1025.jpg
# ./validation/dogs/dog.1091.jpg
# ./validation/dogs/dog.1161.jpg
# ./validation/dogs/dog.1295.jpg
# ./validation/dogs/dog.1040.jpg
# ./validation/dogs/dog.1063.jpg
# ./validation/dogs/dog.1239.jpg
# ./validation/dogs/dog.1131.jpg
# ./validation/dogs/dog.1065.jpg
# ./validation/dogs/dog.1117.jpg
# ./validation/dogs/dog.1277.jpg
# ./validation/dogs/dog.1086.jpg
# ./validation/dogs/dog.1160.jpg
# ./validation/dogs/dog.1163.jpg
# ./validation/dogs/dog.1133.jpg
# ./validation/dogs/dog.1049.jpg
# ./validation/dogs/dog.1141.jpg
# ./validation/dogs/dog.1037.jpg
# ./validation/dogs/dog.1396.jpg
# ./validation/dogs/dog.1241.jpg
# ./validation/dogs/dog.1350.jpg
# ./validation/dogs/dog.1178.jpg
# ./validation/dogs/dog.1378.jpg
# ./validation/dogs/dog.1320.jpg
# ./validation/dogs/dog.1217.jpg
# ./validation/dogs/dog.1181.jpg
# ./validation/dogs/dog.1188.jpg
# ./validation/dogs/dog.1195.jpg
# ./validation/dogs/dog.1280.jpg
# ./validation/dogs/dog.1309.jpg
# ./validation/dogs/dog.1199.jpg
# ./validation/dogs/dog.1260.jpg
# ./validation/dogs/dog.1215.jpg
# ./validation/dogs/dog.1221.jpg
# ./validation/dogs/dog.1000.jpg
# ./validation/dogs/dog.1179.jpg
# ./validation/dogs/dog.1258.jpg
# ./validation/dogs/dog.1094.jpg
# ./validation/dogs/dog.1286.jpg
# ./validation/dogs/dog.1238.jpg
# ./validation/dogs/dog.1193.jpg
# ./validation/dogs/dog.1137.jpg
# ./validation/dogs/dog.1171.jpg
# ./validation/dogs/dog.1224.jpg
# ./validation/dogs/dog.1308.jpg
# ./validation/dogs/dog.1252.jpg
# ./validation/dogs/dog.1372.jpg
# ./validation/dogs/dog.1130.jpg
# ./validation/dogs/dog.1211.jpg
# ./validation/dogs/dog.1274.jpg
# ./validation/dogs/dog.1326.jpg
# ./validation/dogs/dog.1339.jpg
# ./validation/dogs/dog.1159.jpg
# ./validation/dogs/dog.1047.jpg
# ./validation/dogs/dog.1031.jpg
# ./validation/dogs/dog.1358.jpg
# ./validation/dogs/dog.1307.jpg
# ./validation/dogs/dog.1279.jpg
# ./validation/dogs/dog.1344.jpg
# ./validation/dogs/dog.1147.jpg
# ./validation/dogs/dog.1318.jpg
# ./validation/dogs/dog.1300.jpg
# ./validation/dogs/dog.1332.jpg
# ./validation/dogs/dog.1100.jpg
# ./validation/dogs/dog.1026.jpg
# ./validation/dogs/dog.1082.jpg
# ./validation/dogs/dog.1232.jpg
# ./validation/dogs/dog.1126.jpg
# ./validation/dogs/dog.1275.jpg
# ./validation/dogs/dog.1338.jpg
# ./validation/dogs/dog.1379.jpg
# ./validation/dogs/dog.1361.jpg
# ./validation/dogs/dog.1186.jpg
# ./validation/dogs/dog.1083.jpg
# ./validation/dogs/dog.1235.jpg
# ./validation/dogs/dog.1058.jpg
# ./validation/dogs/dog.1185.jpg
# ./validation/dogs/dog.1182.jpg
# ./validation/dogs/dog.1205.jpg
# ./validation/dogs/dog.1078.jpg
# ./validation/dogs/dog.1033.jpg
# ./validation/dogs/dog.1324.jpg
# ./validation/dogs/dog.1346.jpg
# ./validation/dogs/dog.1282.jpg
# ./validation/dogs/dog.1102.jpg
# ./validation/dogs/dog.1120.jpg
# ./validation/dogs/dog.1261.jpg
# ./validation/dogs/dog.1020.jpg
# ./validation/dogs/dog.1143.jpg
# ./validation/dogs/dog.1218.jpg
# ./validation/dogs/dog.1228.jpg
# ./validation/dogs/dog.1084.jpg
# ./validation/dogs/dog.1355.jpg
# ./validation/dogs/dog.1386.jpg
# ./validation/dogs/dog.1002.jpg
# ./validation/dogs/dog.1115.jpg
# ./validation/dogs/dog.1123.jpg
# ./validation/dogs/dog.1024.jpg
# ./validation/dogs/dog.1132.jpg
# ./validation/dogs/dog.1170.jpg
# ./validation/dogs/dog.1398.jpg
# ./validation/dogs/dog.1212.jpg
# ./validation/dogs/dog.1173.jpg
# ./validation/dogs/dog.1189.jpg
# ./validation/dogs/dog.1349.jpg
# ./validation/dogs/dog.1064.jpg
# ./validation/dogs/dog.1032.jpg
# ./validation/dogs/dog.1104.jpg
# ./validation/dogs/dog.1341.jpg
# ./validation/dogs/dog.1303.jpg
# ./validation/dogs/dog.1371.jpg
# ./validation/dogs/dog.1079.jpg
# ./validation/dogs/dog.1342.jpg
# ./validation/dogs/dog.1391.jpg
# ./validation/dogs/dog.1116.jpg
# ./validation/dogs/dog.1263.jpg
# ./validation/dogs/dog.1069.jpg
# ./validation/dogs/dog.1095.jpg
# ./validation/dogs/dog.1085.jpg
# ./validation/dogs/dog.1256.jpg
# ./validation/dogs/dog.1077.jpg
# ./validation/dogs/dog.1266.jpg
# ./validation/dogs/dog.1113.jpg
# ./validation/dogs/dog.1028.jpg
# ./validation/dogs/dog.1110.jpg
# ./validation/dogs/dog.1129.jpg
# ./validation/dogs/dog.1172.jpg
# ./validation/dogs/dog.1184.jpg
# ./validation/dogs/dog.1167.jpg
# ./validation/dogs/dog.1153.jpg
# ./validation/dogs/dog.1248.jpg
# ./validation/dogs/dog.1175.jpg
# ./validation/dogs/dog.1314.jpg
# ./validation/dogs/dog.1335.jpg
# ./validation/dogs/dog.1315.jpg
# ./validation/dogs/dog.1139.jpg
# ./validation/dogs/dog.1213.jpg
# ./validation/dogs/dog.1076.jpg
# ./validation/dogs/dog.1004.jpg
# ./validation/dogs/dog.1388.jpg
# ./validation/dogs/dog.1098.jpg
# ./validation/dogs/dog.1106.jpg
# ./validation/dogs/dog.1021.jpg
# ./validation/dogs/dog.1176.jpg
# ./validation/dogs/dog.1148.jpg
# ./validation/dogs/dog.1128.jpg
# ./validation/dogs/dog.1187.jpg
# ./validation/dogs/dog.1347.jpg
# ./validation/dogs/dog.1267.jpg
# ./validation/dogs/dog.1327.jpg
# ./validation/dogs/dog.1067.jpg
# ./validation/dogs/dog.1018.jpg
# ./validation/dogs/dog.1096.jpg
# ./validation/dogs/dog.1001.jpg
# ./validation/dogs/dog.1036.jpg
# ./validation/dogs/dog.1080.jpg
# ./validation/dogs/dog.1246.jpg
# ./validation/dogs/dog.1369.jpg
# ./validation/dogs/dog.1014.jpg
# ./validation/dogs/dog.1017.jpg
# ./validation/dogs/dog.1015.jpg
# ./validation/dogs/dog.1289.jpg
# ./validation/dogs/dog.1166.jpg
# ./validation/dogs/dog.1220.jpg
# ./validation/dogs/dog.1311.jpg
# ./validation/dogs/dog.1253.jpg
# ./validation/dogs/dog.1390.jpg
# ./validation/dogs/dog.1387.jpg
# ./validation/dogs/dog.1114.jpg
# ./validation/dogs/dog.1146.jpg
# ./validation/dogs/dog.1134.jpg
# ./validation/dogs/dog.1073.jpg
# ./validation/dogs/dog.1124.jpg
# ./validation/dogs/dog.1257.jpg
# ./validation/dogs/dog.1250.jpg
# ./validation/dogs/dog.1125.jpg
# ./validation/dogs/dog.1333.jpg
# ./validation/dogs/dog.1087.jpg
# ./validation/dogs/dog.1385.jpg
# ./validation/dogs/dog.1376.jpg
# ./validation/dogs/dog.1027.jpg
# ./validation/dogs/dog.1365.jpg
# ./validation/dogs/dog.1278.jpg
# ./validation/dogs/dog.1075.jpg
# ./validation/dogs/dog.1151.jpg
# ./validation/dogs/dog.1259.jpg
# ./validation/dogs/dog.1227.jpg
# ./validation/dogs/dog.1255.jpg
# ./validation/dogs/dog.1273.jpg
# ./validation/dogs/dog.1190.jpg
# ./validation/dogs/dog.1360.jpg
# ./validation/dogs/dog.1145.jpg
# ./validation/dogs/dog.1119.jpg
# ./validation/dogs/dog.1330.jpg
# ./validation/dogs/dog.1053.jpg
# ./validation/dogs/dog.1328.jpg
# ./validation/dogs/dog.1362.jpg
# ./validation/dogs/dog.1097.jpg
# ./validation/dogs/dog.1003.jpg
# ./validation/dogs/dog.1380.jpg
# ./validation/dogs/dog.1340.jpg
# ./validation/dogs/dog.1072.jpg
# ./validation/dogs/dog.1231.jpg
# ./validation/dogs/dog.1071.jpg
# ./validation/dogs/dog.1022.jpg
# ./validation/dogs/dog.1262.jpg
# ./validation/dogs/dog.1268.jpg
# ./validation/dogs/dog.1112.jpg
# ./validation/dogs/dog.1270.jpg
# ./validation/dogs/dog.1364.jpg
# ./validation/dogs/dog.1101.jpg
# ./validation/dogs/dog.1039.jpg
# ./validation/dogs/dog.1103.jpg
# ./validation/dogs/dog.1208.jpg
# ./validation/dogs/dog.1206.jpg
# ./validation/dogs/dog.1201.jpg
# ./validation/dogs/dog.1203.jpg
# ./validation/dogs/dog.1283.jpg
# ./validation/dogs/dog.1249.jpg
# ./validation/dogs/dog.1050.jpg
# ./validation/dogs/dog.1169.jpg
# ./validation/dogs/dog.1048.jpg
# ./validation/dogs/dog.1377.jpg
# ./validation/dogs/dog.1038.jpg
# ./validation/dogs/dog.1384.jpg
# ./validation/dogs/dog.1066.jpg
# ./validation/dogs/dog.1236.jpg
# ./validation/dogs/dog.1229.jpg
# ./validation/dogs/dog.1164.jpg
# ./validation/dogs/dog.1111.jpg
# ./validation/dogs/dog.1343.jpg
# ./validation/dogs/dog.1010.jpg
# ./validation/dogs/dog.1200.jpg
# ./validation/dogs/dog.1359.jpg
# ./validation/dogs/dog.1353.jpg
# ./validation/dogs/dog.1045.jpg
# ./validation/dogs/dog.1287.jpg
# ./validation/dogs/dog.1294.jpg
# ./validation/cats/
# ./validation/cats/cat.1316.jpg
# ./validation/cats/cat.1142.jpg
# ./validation/cats/cat.1081.jpg
# ./validation/cats/cat.1118.jpg
# ./validation/cats/cat.1383.jpg
# ./validation/cats/cat.1045.jpg
# ./validation/cats/cat.1190.jpg
# ./validation/cats/cat.1389.jpg
# ./validation/cats/cat.1312.jpg
# ./validation/cats/cat.1002.jpg
# ./validation/cats/cat.1041.jpg
# ./validation/cats/cat.1313.jpg
# ./validation/cats/cat.1034.jpg
# ./validation/cats/cat.1048.jpg
# ./validation/cats/cat.1393.jpg
# ./validation/cats/cat.1036.jpg
# ./validation/cats/cat.1296.jpg
# ./validation/cats/cat.1374.jpg
# ./validation/cats/cat.1308.jpg
# ./validation/cats/cat.1293.jpg
# ./validation/cats/cat.1256.jpg
# ./validation/cats/cat.1201.jpg
# ./validation/cats/cat.1100.jpg
# ./validation/cats/cat.1103.jpg
# ./validation/cats/cat.1136.jpg
# ./validation/cats/cat.1033.jpg
# ./validation/cats/cat.1112.jpg
# ./validation/cats/cat.1022.jpg
# ./train/dogs/dog.835.jpg
# ./train/dogs/dog.518.jpg
# ./train/dogs/dog.927.jpg
# ./train/dogs/dog.977.jpg
# ./train/dogs/dog.818.jpg
# ./train/dogs/dog.7.jpg
# ./train/dogs/dog.929.jpg
# ./train/dogs/dog.914.jpg
# ./train/dogs/dog.529.jpg
# ./train/dogs/dog.963.jpg
# ./train/dogs/dog.312.jpg
# ./train/dogs/dog.89.jpg
# ./train/dogs/dog.741.jpg
# ./train/dogs/dog.154.jpg
# ./train/dogs/dog.609.jpg
# ./train/dogs/dog.986.jpg
# ./train/dogs/dog.573.jpg
# ./train/dogs/dog.660.jpg
# ./train/dogs/dog.42.jpg
# ./train/dogs/dog.114.jpg
# ./train/dogs/dog.782.jpg
# ./train/dogs/dog.890.jpg
# ./train/dogs/dog.243.jpg
# ./train/dogs/dog.817.jpg
# ./train/dogs/dog.891.jpg
# ./train/dogs/dog.738.jpg
# ./train/dogs/dog.199.jpg
# ./train/dogs/dog.861.jpg
# ./train/dogs/dog.309.jpg
# ./train/dogs/dog.827.jpg
# ./train/dogs/dog.603.jpg
# ./train/dogs/dog.643.jpg
# ./train/dogs/dog.802.jpg
# ./train/dogs/dog.147.jpg
# ./train/dogs/dog.362.jpg
# ./train/dogs/dog.286.jpg
# ./train/dogs/dog.989.jpg
# ./train/dogs/dog.949.jpg
# ./train/dogs/dog.590.jpg
# ./train/dogs/dog.629.jpg
# ./train/dogs/dog.870.jpg
# ./train/dogs/dog.832.jpg
# ./train/dogs/dog.540.jpg
# ./train/dogs/dog.291.jpg
# ./train/dogs/dog.373.jpg
# ./train/dogs/dog.175.jpg
# ./train/dogs/dog.734.jpg
# ./train/dogs/dog.720.jpg
# ./train/dogs/dog.477.jpg
# ./train/dogs/dog.455.jpg
# ./train/dogs/dog.302.jpg
# ./train/dogs/dog.813.jpg
# ./train/dogs/dog.777.jpg
# ./train/dogs/dog.310.jpg
# ./train/dogs/dog.978.jpg
# ./train/dogs/dog.358.jpg
# ./train/dogs/dog.351.jpg
# ./train/dogs/dog.319.jpg
# ./train/dogs/dog.303.jpg
# ./train/dogs/dog.419.jpg
# ./train/dogs/dog.909.jpg
# ./train/dogs/dog.797.jpg
# ./train/dogs/dog.353.jpg
# ./train/dogs/dog.872.jpg
# ./train/dogs/dog.516.jpg
# ./train/dogs/dog.793.jpg
# ./train/dogs/dog.108.jpg
# ./train/dogs/dog.239.jpg
# ./train/dogs/dog.375.jpg
# ./train/dogs/dog.400.jpg
# ./train/dogs/dog.970.jpg
# ./train/dogs/dog.443.jpg
# ./train/dogs/dog.273.jpg
# ./train/dogs/dog.54.jpg
# ./train/dogs/dog.834.jpg
# ./train/dogs/dog.731.jpg
# ./train/dogs/dog.748.jpg
# ./train/dogs/dog.50.jpg
# ./train/dogs/dog.260.jpg
# ./train/dogs/dog.762.jpg
# ./train/dogs/dog.504.jpg
# ./train/dogs/dog.28.jpg
# ./train/dogs/dog.100.jpg
# ./train/dogs/dog.360.jpg
# ./train/dogs/dog.803.jpg
# ./train/dogs/dog.593.jpg
# ./train/dogs/dog.109.jpg
# ./train/dogs/dog.350.jpg
# ./train/dogs/dog.580.jpg
# ./train/dogs/dog.374.jpg
# ./train/dogs/dog.405.jpg
# ./train/dogs/dog.982.jpg
# ./train/dogs/dog.496.jpg
# ./train/dogs/dog.503.jpg
# ./train/dogs/dog.739.jpg
# ./train/dogs/dog.173.jpg
# ./train/dogs/dog.965.jpg
# ./train/dogs/dog.897.jpg
# ./train/dogs/dog.836.jpg
# ./train/dogs/dog.823.jpg
# ./train/dogs/dog.932.jpg
# ./train/dogs/dog.666.jpg
# ./train/dogs/dog.831.jpg
# ./train/dogs/dog.845.jpg
# ./train/dogs/dog.79.jpg
# ./train/dogs/dog.869.jpg
# ./train/dogs/dog.372.jpg
# ./train/dogs/dog.592.jpg
# ./train/dogs/dog.210.jpg
# ./train/dogs/dog.895.jpg
# ./train/dogs/dog.153.jpg
# ./train/dogs/dog.538.jpg
# ./train/dogs/dog.420.jpg
# ./train/dogs/dog.480.jpg
# ./train/dogs/dog.151.jpg
# ./train/dogs/dog.788.jpg
# ./train/dogs/dog.554.jpg
# ./train/dogs/dog.644.jpg
# ./train/dogs/dog.871.jpg
# ./train/dogs/dog.620.jpg
# ./train/dogs/dog.745.jpg
# ./train/dogs/dog.507.jpg
# ./train/dogs/dog.398.jpg
# ./train/dogs/dog.610.jpg
# ./train/dogs/dog.444.jpg
# ./train/dogs/dog.194.jpg
# ./train/dogs/dog.656.jpg
# ./train/dogs/dog.657.jpg
# ./train/dogs/dog.433.jpg
# ./train/dogs/dog.411.jpg
# ./train/dogs/dog.655.jpg
# ./train/dogs/dog.740.jpg
# ./train/dogs/dog.947.jpg
# ./train/dogs/dog.425.jpg
# ./train/dogs/dog.723.jpg
# ./train/dogs/dog.370.jpg
# ./train/dogs/dog.935.jpg
# ./train/dogs/dog.341.jpg
# ./train/dogs/dog.645.jpg
# ./train/dogs/dog.759.jpg
# ./train/dogs/dog.707.jpg
# ./train/dogs/dog.787.jpg
# ./train/dogs/dog.406.jpg
# ./train/dogs/dog.394.jpg
# ./train/dogs/dog.864.jpg
# ./train/dogs/dog.885.jpg
# ./train/dogs/dog.565.jpg
# ./train/dogs/dog.912.jpg
# ./train/dogs/dog.384.jpg
# ./train/dogs/dog.790.jpg
# ./train/dogs/dog.378.jpg
# ./train/dogs/dog.94.jpg
# ./train/dogs/dog.399.jpg
# ./train/dogs/dog.298.jpg
# ./train/dogs/dog.143.jpg
# ./train/dogs/dog.651.jpg
# ./train/dogs/dog.412.jpg
# ./train/dogs/dog.900.jpg
# ./train/dogs/dog.950.jpg
# ./train/dogs/dog.92.jpg
# ./train/dogs/dog.674.jpg
# ./train/dogs/dog.184.jpg
# ./train/dogs/dog.548.jpg
# ./train/dogs/dog.39.jpg
# ./train/dogs/dog.475.jpg
# ./train/dogs/dog.198.jpg
# ./train/dogs/dog.969.jpg
# ./train/dogs/dog.429.jpg
# ./train/dogs/dog.737.jpg
# ./train/dogs/dog.21.jpg
# ./train/dogs/dog.78.jpg
# ./train/dogs/dog.234.jpg
# ./train/dogs/dog.314.jpg
# ./train/dogs/dog.75.jpg
# ./train/dogs/dog.933.jpg
# ./train/dogs/dog.415.jpg
# ./train/dogs/dog.161.jpg
# ./train/dogs/dog.500.jpg
# ./train/dogs/dog.408.jpg
# ./train/dogs/dog.148.jpg
# ./train/dogs/dog.189.jpg
# ./train/dogs/dog.495.jpg
# ./train/dogs/dog.966.jpg
# ./train/dogs/dog.471.jpg
# ./train/dogs/dog.277.jpg
# ./train/dogs/dog.233.jpg
# ./train/dogs/dog.167.jpg
# ./train/dogs/dog.487.jpg
# ./train/dogs/dog.159.jpg
# ./train/dogs/dog.697.jpg
# ./train/dogs/dog.976.jpg
# ./train/dogs/dog.293.jpg
# ./train/dogs/dog.157.jpg
# ./train/dogs/dog.926.jpg
# ./train/dogs/dog.299.jpg
# ./train/dogs/dog.325.jpg
# ./train/dogs/dog.44.jpg
# ./train/dogs/dog.635.jpg
# ./train/dogs/dog.268.jpg
# ./train/dogs/dog.675.jpg
# ./train/dogs/dog.742.jpg
# ./train/dogs/dog.552.jpg
# ./train/dogs/dog.751.jpg
# ./train/dogs/dog.271.jpg
# ./train/dogs/dog.792.jpg
# ./train/dogs/dog.178.jpg
# ./train/dogs/dog.703.jpg
# ./train/dogs/dog.502.jpg
# ./train/dogs/dog.193.jpg
# ./train/dogs/dog.266.jpg
# ./train/dogs/dog.886.jpg
# ./train/dogs/dog.875.jpg
# ./train/dogs/dog.954.jpg
# ./train/dogs/dog.689.jpg
# ./train/dogs/dog.810.jpg
# ./train/dogs/dog.101.jpg
# ./train/dogs/dog.776.jpg
# ./train/dogs/dog.242.jpg
# ./train/dogs/dog.847.jpg
# ./train/dogs/dog.860.jpg
# ./train/dogs/dog.127.jpg
# ./train/dogs/dog.404.jpg
# ./train/dogs/dog.476.jpg
# ./train/dogs/dog.850.jpg
# ./train/dogs/dog.998.jpg
# ./train/dogs/dog.343.jpg
# ./train/dogs/dog.170.jpg
# ./train/dogs/dog.706.jpg
# ./train/dogs/dog.903.jpg
# ./train/dogs/dog.956.jpg
# ./train/dogs/dog.261.jpg
# ./train/dogs/dog.130.jpg
# ./train/dogs/dog.763.jpg
# ./train/dogs/dog.473.jpg
# ./train/dogs/dog.396.jpg
# ./train/dogs/dog.196.jpg
# ./train/dogs/dog.331.jpg
# ./train/dogs/dog.354.jpg
# ./train/dogs/dog.513.jpg
# ./train/dogs/dog.961.jpg
# ./train/dogs/dog.527.jpg
# ./train/dogs/dog.180.jpg
# ./train/dogs/dog.634.jpg
# ./train/dogs/dog.177.jpg
# ./train/dogs/dog.181.jpg
# ./train/dogs/dog.806.jpg
# ./train/dogs/dog.921.jpg
# ./train/dogs/dog.773.jpg
# ./train/dogs/dog.699.jpg
# ./train/dogs/dog.811.jpg
# ./train/dogs/dog.434.jpg
# ./train/dogs/dog.99.jpg
# ./train/dogs/dog.944.jpg
# ./train/dogs/dog.311.jpg
# ./train/dogs/dog.122.jpg
# ./train/dogs/dog.381.jpg
# ./train/dogs/dog.241.jpg
# ./train/dogs/dog.757.jpg
# ./train/dogs/dog.991.jpg
# ./train/dogs/dog.733.jpg
# ./train/dogs/dog.747.jpg
# ./train/dogs/dog.750.jpg
# ./train/dogs/dog.203.jpg
# ./train/dogs/dog.840.jpg
# ./train/dogs/dog.744.jpg
# ./train/dogs/dog.510.jpg
# ./train/dogs/dog.544.jpg
# ./train/dogs/dog.557.jpg
# ./train/dogs/dog.355.jpg
# ./train/dogs/dog.925.jpg
# ./train/dogs/dog.615.jpg
# ./train/dogs/dog.73.jpg
# ./train/dogs/dog.16.jpg
# ./train/dogs/dog.729.jpg
# ./train/dogs/dog.270.jpg
# ./train/dogs/dog.251.jpg
# ./train/dogs/dog.401.jpg
# ./train/dogs/dog.51.jpg
# ./train/dogs/dog.794.jpg
# ./train/dogs/dog.290.jpg
# ./train/dogs/dog.342.jpg
# ./train/dogs/dog.924.jpg
# ./train/dogs/dog.22.jpg
# ./train/dogs/dog.136.jpg
# ./train/dogs/dog.292.jpg
# ./train/dogs/dog.47.jpg
# ./train/dogs/dog.427.jpg
# ./train/dogs/dog.799.jpg
# ./train/dogs/dog.18.jpg
# ./train/dogs/dog.115.jpg
# ./train/dogs/dog.841.jpg
# ./train/dogs/dog.34.jpg
# ./train/dogs/dog.795.jpg
# ./train/dogs/dog.659.jpg
# ./train/dogs/dog.390.jpg
# ./train/dogs/dog.649.jpg
# ./train/dogs/dog.849.jpg
# ./train/dogs/dog.664.jpg
# ./train/dogs/dog.854.jpg
# ./train/dogs/dog.668.jpg
# ./train/dogs/dog.857.jpg
# ./train/dogs/dog.667.jpg
# ./train/dogs/dog.772.jpg
# ./train/dogs/dog.82.jpg
# ./train/dogs/dog.547.jpg
# ./train/dogs/dog.445.jpg
# ./train/dogs/dog.685.jpg
# ./train/dogs/dog.521.jpg
# ./train/dogs/dog.715.jpg
# ./train/dogs/dog.873.jpg
# ./train/dogs/dog.216.jpg
# ./train/dogs/dog.426.jpg
# ./train/dogs/dog.361.jpg
# ./train/dogs/dog.526.jpg
# ./train/dogs/dog.183.jpg
# ./train/dogs/dog.984.jpg
# ./train/dogs/dog.285.jpg
# ./train/dogs/dog.11.jpg
# ./train/dogs/dog.333.jpg
# ./train/dogs/dog.221.jpg
# ./train/dogs/dog.654.jpg
# ./train/dogs/dog.994.jpg
# ./train/dogs/dog.843.jpg
# ./train/dogs/dog.726.jpg
# ./train/dogs/dog.589.jpg
# ./train/dogs/dog.617.jpg
# ./train/dogs/dog.769.jpg
# ./train/dogs/dog.753.jpg
# ./train/dogs/dog.76.jpg
# ./train/dogs/dog.815.jpg
# ./train/dogs/dog.395.jpg
# ./train/dogs/dog.928.jpg
# ./train/dogs/dog.229.jpg
# ./train/dogs/dog.658.jpg
# ./train/dogs/dog.391.jpg
# ./train/dogs/dog.272.jpg
# ./train/dogs/dog.511.jpg
# ./train/dogs/dog.23.jpg
# ./train/dogs/dog.570.jpg
# ./train/dogs/dog.882.jpg
# ./train/dogs/dog.55.jpg
# ./train/dogs/dog.555.jpg
# ./train/dogs/dog.567.jpg
# ./train/dogs/dog.140.jpg
# ./train/dogs/dog.3.jpg
# ./train/dogs/dog.235.jpg
# ./train/dogs/dog.324.jpg
# ./train/dogs/dog.711.jpg
# ./train/dogs/dog.142.jpg
# ./train/dogs/dog.902.jpg
# ./train/dogs/dog.133.jpg
# ./train/dogs/dog.269.jpg
# ./train/dogs/dog.997.jpg
# ./train/dogs/dog.335.jpg
# ./train/dogs/dog.691.jpg
# ./train/dogs/dog.564.jpg
# ./train/dogs/dog.541.jpg
# ./train/dogs/dog.804.jpg
# ./train/dogs/dog.874.jpg
# ./train/dogs/dog.435.jpg
# ./train/dogs/dog.138.jpg
# ./train/dogs/dog.866.jpg
# ./train/dogs/dog.450.jpg
# ./train/dogs/dog.798.jpg
# ./train/dogs/dog.535.jpg
# ./train/dogs/dog.141.jpg
# ./train/dogs/dog.219.jpg
# ./train/dogs/dog.910.jpg
# ./train/dogs/dog.490.jpg
# ./train/dogs/dog.597.jpg
# ./train/dogs/dog.469.jpg
# ./train/dogs/dog.315.jpg
# ./train/dogs/dog.856.jpg
# ./train/dogs/dog.389.jpg
# ./train/dogs/dog.545.jpg
# ./train/dogs/dog.295.jpg
# ./train/dogs/dog.456.jpg
# ./train/dogs/dog.749.jpg
# ./train/dogs/dog.117.jpg
# ./train/dogs/dog.15.jpg
# ./train/dogs/dog.936.jpg
# ./train/dogs/dog.858.jpg
# ./train/dogs/dog.30.jpg
# ./train/dogs/dog.248.jpg
# ./train/dogs/dog.225.jpg
# ./train/dogs/dog.611.jpg
# ./train/dogs/dog.344.jpg
# ./train/dogs/dog.413.jpg
# ./train/dogs/dog.650.jpg
# ./train/dogs/dog.680.jpg
# ./train/dogs/dog.72.jpg
# ./train/dogs/dog.348.jpg
# ./train/dogs/dog.825.jpg
# ./train/dogs/dog.767.jpg
# ./train/dogs/dog.103.jpg
# ./train/dogs/dog.534.jpg
# ./train/dogs/dog.494.jpg
# ./train/dogs/dog.150.jpg
# ./train/dogs/dog.393.jpg
# ./train/dogs/dog.364.jpg
# ./train/dogs/dog.263.jpg
# ./train/dogs/dog.431.jpg
# ./train/dogs/dog.713.jpg
# ./train/dogs/dog.112.jpg
# ./train/dogs/dog.186.jpg
# ./train/dogs/dog.915.jpg
# ./train/dogs/dog.397.jpg
# ./train/dogs/dog.264.jpg
# ./train/dogs/dog.800.jpg
# ./train/dogs/dog.930.jpg
# ./train/dogs/dog.746.jpg
# ./train/dogs/dog.352.jpg
# ./train/dogs/dog.514.jpg
# ./train/dogs/dog.287.jpg
# ./train/dogs/dog.665.jpg
# ./train/dogs/dog.848.jpg
# ./train/dogs/dog.166.jpg
# ./train/dogs/dog.607.jpg
# ./train/dogs/dog.596.jpg
# ./train/dogs/dog.459.jpg
# ./train/dogs/dog.536.jpg
# ./train/dogs/dog.67.jpg
# ./train/dogs/dog.679.jpg
# ./train/dogs/dog.628.jpg
# ./train/dogs/dog.218.jpg
# ./train/dogs/dog.574.jpg
# ./train/dogs/dog.778.jpg
# ./train/dogs/dog.714.jpg
# ./train/dogs/dog.385.jpg
# ./train/dogs/dog.896.jpg
# ./train/dogs/dog.363.jpg
# ./train/dogs/dog.38.jpg
# ./train/dogs/dog.388.jpg
# ./train/dogs/dog.458.jpg
# ./train/dogs/dog.595.jpg
# ./train/dogs/dog.386.jpg
# ./train/dogs/dog.139.jpg
# ./train/dogs/dog.185.jpg
# ./train/dogs/dog.85.jpg
# ./train/dogs/dog.766.jpg
# ./train/dogs/dog.623.jpg
# ./train/dogs/dog.437.jpg
# ./train/dogs/dog.332.jpg
# ./train/dogs/dog.377.jpg
# ./train/dogs/dog.698.jpg
# ./train/dogs/dog.517.jpg
# ./train/dogs/dog.964.jpg
# ./train/dogs/dog.696.jpg
# ./train/dogs/dog.146.jpg
# ./train/dogs/dog.182.jpg
# ./train/dogs/dog.913.jpg
# ./train/dogs/dog.662.jpg
# ./train/dogs/dog.876.jpg
# ./train/dogs/dog.96.jpg
# ./train/dogs/dog.304.jpg
# ./train/dogs/dog.20.jpg
# ./train/dogs/dog.417.jpg
# ./train/dogs/dog.197.jpg
# ./train/dogs/dog.252.jpg
# ./train/dogs/dog.145.jpg
# ./train/dogs/dog.879.jpg
# ./train/dogs/dog.704.jpg
# ./train/dogs/dog.376.jpg
# ./train/dogs/dog.865.jpg
# ./train/dogs/dog.52.jpg
# ./train/dogs/dog.678.jpg
# ./train/dogs/dog.702.jpg
# ./train/dogs/dog.83.jpg
# ./train/dogs/dog.64.jpg
# ./train/dogs/dog.585.jpg
# ./train/dogs/dog.230.jpg
# ./train/dogs/dog.542.jpg
# ./train/dogs/dog.0.jpg
# ./train/dogs/dog.883.jpg
# ./train/dogs/dog.297.jpg
# ./train/dogs/dog.40.jpg
# ./train/dogs/dog.32.jpg
# ./train/dogs/dog.308.jpg
# ./train/dogs/dog.862.jpg
# ./train/dogs/dog.533.jpg
# ./train/dogs/dog.489.jpg
# ./train/dogs/dog.442.jpg
# ./train/dogs/dog.200.jpg
# ./train/dogs/dog.410.jpg
# ./train/dogs/dog.125.jpg
# ./train/dogs/dog.232.jpg
# ./train/dogs/dog.546.jpg
# ./train/dogs/dog.2.jpg
# ./train/dogs/dog.493.jpg
# ./train/dogs/dog.137.jpg
# ./train/dogs/dog.58.jpg
# ./train/dogs/dog.721.jpg
# ./train/dogs/dog.223.jpg
# ./train/dogs/dog.633.jpg
# ./train/dogs/dog.110.jpg
# ./train/dogs/dog.65.jpg
# ./train/dogs/dog.26.jpg
# ./train/dogs/dog.126.jpg
# ./train/dogs/dog.93.jpg
# ./train/dogs/dog.440.jpg
# ./train/dogs/dog.948.jpg
# ./train/dogs/dog.155.jpg
# ./train/dogs/dog.563.jpg
# ./train/dogs/dog.346.jpg
# ./train/dogs/dog.90.jpg
# ./train/dogs/dog.228.jpg
# ./train/dogs/dog.846.jpg
# ./train/dogs/dog.227.jpg
# ./train/dogs/dog.584.jpg
# ./train/dogs/dog.687.jpg
# ./train/dogs/dog.684.jpg
# ./train/dogs/dog.414.jpg
# ./train/dogs/dog.35.jpg
# ./train/dogs/dog.43.jpg
# ./train/dogs/dog.937.jpg
# ./train/dogs/dog.550.jpg
# ./train/dogs/dog.775.jpg
# ./train/dogs/dog.716.jpg
# ./train/dogs/dog.919.jpg
# ./train/dogs/dog.466.jpg
# ./train/dogs/dog.705.jpg
# ./train/dogs/dog.648.jpg
# ./train/dogs/dog.591.jpg
# ./train/dogs/dog.498.jpg
# ./train/dogs/dog.168.jpg
# ./train/dogs/dog.447.jpg
# ./train/dogs/dog.174.jpg
# ./train/dogs/dog.646.jpg
# ./train/dogs/dog.816.jpg
# ./train/dogs/dog.524.jpg
# ./train/dogs/dog.624.jpg
# ./train/dogs/dog.60.jpg
# ./train/dogs/dog.402.jpg
# ./train/dogs/dog.980.jpg
# ./train/dogs/dog.247.jpg
# ./train/dogs/dog.828.jpg
# ./train/dogs/dog.789.jpg
# ./train/dogs/dog.211.jpg
# ./train/dogs/dog.725.jpg
# ./train/dogs/dog.119.jpg
# ./train/dogs/dog.911.jpg
# ./train/dogs/dog.598.jpg
# ./train/dogs/dog.830.jpg
# ./train/dogs/dog.987.jpg
# ./train/dogs/dog.382.jpg
# ./train/dogs/dog.120.jpg
# ./train/dogs/dog.19.jpg
# ./train/dogs/dog.284.jpg
# ./train/dogs/dog.796.jpg
# ./train/dogs/dog.688.jpg
# ./train/dogs/dog.852.jpg
# ./train/dogs/dog.549.jpg
# ./train/dogs/dog.824.jpg
# ./train/dogs/dog.107.jpg
# ./train/dogs/dog.205.jpg
# ./train/dogs/dog.492.jpg
# ./train/dogs/dog.953.jpg
# ./train/dogs/dog.807.jpg
# ./train/dogs/dog.774.jpg
# ./train/dogs/dog.37.jpg
# ./train/dogs/dog.622.jpg
# ./train/dogs/dog.330.jpg
# ./train/dogs/dog.129.jpg
# ./train/dogs/dog.880.jpg
# ./train/dogs/dog.768.jpg
# ./train/dogs/dog.470.jpg
# ./train/dogs/dog.606.jpg
# ./train/dogs/dog.367.jpg
# ./train/dogs/dog.627.jpg
# ./train/dogs/dog.320.jpg
# ./train/dogs/dog.670.jpg
# ./train/dogs/dog.531.jpg
# ./train/dogs/dog.988.jpg
# ./train/dogs/dog.898.jpg
# ./train/dogs/dog.488.jpg
# ./train/dogs/dog.839.jpg
# ./train/dogs/dog.439.jpg
# ./train/dogs/dog.735.jpg
# ./train/dogs/dog.905.jpg
# ./train/dogs/dog.416.jpg
# ./train/dogs/dog.365.jpg
# ./train/dogs/dog.571.jpg
# ./train/dogs/dog.637.jpg
# ./train/dogs/dog.583.jpg
# ./train/dogs/dog.962.jpg
# ./train/dogs/dog.632.jpg
# ./train/dogs/dog.581.jpg
# ./train/dogs/dog.561.jpg
# ./train/dogs/dog.519.jpg
# ./train/dogs/dog.49.jpg
# ./train/dogs/dog.465.jpg
# ./train/dogs/dog.608.jpg
# ./train/dogs/dog.783.jpg
# ./train/dogs/dog.305.jpg
# ./train/dogs/dog.222.jpg
# ./train/dogs/dog.537.jpg
# ./train/dogs/dog.481.jpg
# ./train/dogs/dog.732.jpg
# ./train/dogs/dog.647.jpg
# ./train/dogs/dog.403.jpg
# ./train/dogs/dog.104.jpg
# ./train/dogs/dog.249.jpg
# ./train/dogs/dog.671.jpg
# ./train/dogs/dog.191.jpg
# ./train/dogs/dog.366.jpg
# ./train/dogs/dog.349.jpg
# ./train/dogs/dog.878.jpg
# ./train/dogs/dog.669.jpg
# ./train/dogs/dog.940.jpg
# ./train/dogs/dog.454.jpg
# ./train/dogs/dog.379.jpg
# ./train/dogs/dog.485.jpg
# ./train/dogs/dog.483.jpg
# ./train/dogs/dog.321.jpg
# ./train/dogs/dog.868.jpg
# ./train/dogs/dog.226.jpg
# ./train/dogs/dog.844.jpg
# ./train/dogs/dog.829.jpg
# ./train/dogs/dog.472.jpg
# ./train/dogs/dog.887.jpg
# ./train/dogs/dog.327.jpg
# ./train/dogs/dog.214.jpg
# ./train/dogs/dog.918.jpg
# ./train/dogs/dog.457.jpg
# ./train/dogs/dog.77.jpg
# ./train/dogs/dog.821.jpg
# ./train/dogs/dog.14.jpg
# ./train/dogs/dog.572.jpg
# ./train/dogs/dog.945.jpg
# ./train/dogs/dog.586.jpg
# ./train/dogs/dog.316.jpg
# ./train/dogs/dog.631.jpg
# ./train/dogs/dog.164.jpg
# ./train/dogs/dog.576.jpg
# ./train/dogs/dog.474.jpg
# ./train/dogs/dog.322.jpg
# ./train/dogs/dog.131.jpg
# ./train/dogs/dog.951.jpg
# ./train/dogs/dog.614.jpg
# ./train/dogs/dog.340.jpg
# ./train/dogs/dog.578.jpg
# ./train/dogs/dog.258.jpg
# ./train/dogs/dog.274.jpg
# ./train/dogs/dog.33.jpg
# ./train/dogs/dog.959.jpg
# ./train/dogs/dog.231.jpg
# ./train/dogs/dog.482.jpg
# ./train/dogs/dog.409.jpg
# ./train/dogs/dog.505.jpg
# ./train/dogs/dog.863.jpg
# ./train/dogs/dog.958.jpg
# ./train/dogs/dog.105.jpg
# ./train/dogs/dog.957.jpg
# ./train/dogs/dog.638.jpg
# ./train/dogs/dog.508.jpg
# ./train/dogs/dog.61.jpg
# ./train/dogs/dog.446.jpg
# ./train/dogs/dog.785.jpg
# ./train/dogs/dog.451.jpg
# ./train/dogs/dog.512.jpg
# ./train/dogs/dog.452.jpg
# ./train/dogs/dog.594.jpg
# ./train/dogs/dog.916.jpg
# ./train/dogs/dog.169.jpg
# ./train/dogs/dog.467.jpg
# ./train/dogs/dog.392.jpg
# ./train/dogs/dog.770.jpg
# ./train/dogs/dog.436.jpg
# ./train/dogs/dog.192.jpg
# ./train/dogs/dog.842.jpg
# ./train/dogs/dog.556.jpg
# ./train/dogs/dog.920.jpg
# ./train/dogs/dog.121.jpg
# ./train/dogs/dog.694.jpg
# ./train/dogs/dog.922.jpg
# ./train/dogs/dog.602.jpg
# ./train/dogs/dog.250.jpg
# ./train/dogs/dog.973.jpg
# ./train/dogs/dog.641.jpg
# ./train/dogs/dog.224.jpg
# ./train/dogs/dog.683.jpg
# ./train/dogs/dog.4.jpg
# ./train/dogs/dog.755.jpg
# ./train/dogs/dog.814.jpg
# ./train/dogs/dog.754.jpg
# ./train/dogs/dog.543.jpg
# ./train/dogs/dog.801.jpg
# ./train/dogs/dog.202.jpg
# ./train/dogs/dog.522.jpg
# ./train/dogs/dog.600.jpg
# ./train/dogs/dog.255.jpg
# ./train/dogs/dog.838.jpg
# ./train/dogs/dog.972.jpg
# ./train/dogs/dog.179.jpg
# ./train/dogs/dog.116.jpg
# ./train/dogs/dog.515.jpg
# ./train/dogs/dog.736.jpg
# ./train/dogs/dog.53.jpg
# ./train/dogs/dog.577.jpg
# ./train/dogs/dog.347.jpg
# ./train/dogs/dog.917.jpg
# ./train/dogs/dog.9.jpg
# ./train/dogs/dog.267.jpg
# ./train/dogs/dog.463.jpg
# ./train/dogs/dog.618.jpg
# ./train/dogs/dog.81.jpg
# ./train/dogs/dog.123.jpg
# ./train/dogs/dog.968.jpg
# ./train/dogs/dog.506.jpg
# ./train/dogs/dog.152.jpg
# ./train/dogs/dog.118.jpg
# ./train/dogs/dog.276.jpg
# ./train/dogs/dog.428.jpg
# ./train/dogs/dog.371.jpg
# ./train/dogs/dog.993.jpg
# ./train/dogs/dog.931.jpg
# ./train/dogs/dog.165.jpg
# ./train/dogs/dog.88.jpg
# ./train/dogs/dog.904.jpg
# ./train/dogs/dog.636.jpg
# ./train/dogs/dog.881.jpg
# ./train/dogs/dog.663.jpg
# ./train/dogs/dog.432.jpg
# ./train/dogs/dog.599.jpg
# ./train/dogs/dog.262.jpg
# ./train/dogs/dog.461.jpg
# ./train/dogs/dog.995.jpg
# ./train/dogs/dog.484.jpg
# ./train/dogs/dog.613.jpg
# ./train/dogs/dog.345.jpg
# ./train/dogs/dog.653.jpg
# ./train/dogs/dog.80.jpg
# ./train/dogs/dog.985.jpg
# ./train/dogs/dog.569.jpg
# ./train/dogs/dog.156.jpg
# ./train/dogs/dog.176.jpg
# ./train/dogs/dog.758.jpg
# ./train/dogs/dog.387.jpg
# ./train/dogs/dog.717.jpg
# ./train/dogs/dog.106.jpg
# ./train/dogs/dog.421.jpg
# ./train/dogs/dog.710.jpg
# ./train/dogs/dog.727.jpg
# ./train/dogs/dog.423.jpg
# ./train/dogs/dog.326.jpg
# ./train/dogs/dog.686.jpg
# ./train/dogs/dog.923.jpg
# ./train/dogs/dog.188.jpg
# ./train/dogs/dog.438.jpg
# ./train/dogs/dog.560.jpg
# ./train/dogs/dog.718.jpg
# ./train/dogs/dog.238.jpg
# ./train/dogs/dog.430.jpg
# ./train/dogs/dog.245.jpg
# ./train/dogs/dog.86.jpg
# ./train/dogs/dog.604.jpg
# ./train/dogs/dog.999.jpg
# ./train/dogs/dog.278.jpg
# ./train/dogs/dog.851.jpg
# ./train/dogs/dog.418.jpg
# ./train/dogs/dog.158.jpg
# ./train/dogs/dog.728.jpg
# ./train/dogs/dog.12.jpg
# ./train/dogs/dog.701.jpg
# ./train/dogs/dog.329.jpg
# ./train/dogs/dog.27.jpg
# ./train/dogs/dog.306.jpg
# ./train/dogs/dog.380.jpg
# ./train/dogs/dog.339.jpg
# ./train/dogs/dog.31.jpg
# ./train/dogs/dog.661.jpg
# ./train/dogs/dog.5.jpg
# ./train/dogs/dog.786.jpg
# ./train/dogs/dog.805.jpg
# ./train/dogs/dog.259.jpg
# ./train/dogs/dog.942.jpg
# ./train/dogs/dog.17.jpg
# ./train/dogs/dog.677.jpg
# ./train/dogs/dog.676.jpg
# ./train/dogs/dog.10.jpg
# ./train/dogs/dog.283.jpg
# ./train/dogs/dog.59.jpg
# ./train/dogs/dog.943.jpg
# ./train/dogs/dog.453.jpg
# ./train/dogs/dog.894.jpg
# ./train/dogs/dog.468.jpg
# ./train/dogs/dog.952.jpg
# ./train/dogs/dog.41.jpg
# ./train/dogs/dog.566.jpg
# ./train/dogs/dog.612.jpg
# ./train/dogs/dog.672.jpg
# ./train/dogs/dog.486.jpg
# ./train/dogs/dog.162.jpg
# ./train/dogs/dog.743.jpg
# ./train/dogs/dog.334.jpg
# ./train/dogs/dog.722.jpg
# ./train/dogs/dog.246.jpg
# ./train/dogs/dog.621.jpg
# ./train/dogs/dog.779.jpg
# ./train/dogs/dog.681.jpg
# ./train/dogs/dog.213.jpg
# ./train/dogs/dog.149.jpg
# ./train/dogs/dog.95.jpg
# ./train/dogs/dog.323.jpg
# ./train/dogs/dog.941.jpg
# ./train/dogs/dog.558.jpg
# ./train/dogs/dog.812.jpg
# ./train/dogs/dog.771.jpg
# ./train/dogs/dog.132.jpg
# ./train/dogs/dog.530.jpg
# ./train/dogs/dog.709.jpg
# ./train/dogs/dog.172.jpg
# ./train/dogs/dog.296.jpg
# ./train/dogs/dog.491.jpg
# ./train/dogs/dog.294.jpg
# ./train/dogs/dog.209.jpg
# ./train/dogs/dog.207.jpg
# ./train/dogs/dog.938.jpg
# ./train/dogs/dog.539.jpg
# ./train/dogs/dog.901.jpg
# ./train/dogs/dog.616.jpg
# ./train/dogs/dog.56.jpg
# ./train/dogs/dog.760.jpg
# ./train/dogs/dog.588.jpg
# ./train/dogs/dog.724.jpg
# ./train/dogs/dog.187.jpg
# ./train/dogs/dog.357.jpg
# ./train/dogs/dog.57.jpg
# ./train/dogs/dog.765.jpg
# ./train/dogs/dog.990.jpg
# ./train/dogs/dog.201.jpg
# ./train/dogs/dog.626.jpg
# ./train/dogs/dog.338.jpg
# ./train/dogs/dog.630.jpg
# ./train/dogs/dog.791.jpg
# ./train/dogs/dog.301.jpg
# ./train/dogs/dog.253.jpg
# ./train/dogs/dog.215.jpg
# ./train/dogs/dog.441.jpg
# ./train/dogs/dog.8.jpg
# ./train/dogs/dog.279.jpg
# ./train/dogs/dog.336.jpg
# ./train/dogs/dog.111.jpg
# ./train/dogs/dog.907.jpg
# ./train/dogs/dog.568.jpg
# ./train/dogs/dog.91.jpg
# ./train/dogs/dog.877.jpg
# ./train/dogs/dog.134.jpg
# ./train/dogs/dog.975.jpg
# ./train/dogs/dog.84.jpg
# ./train/dogs/dog.135.jpg
# ./train/dogs/dog.13.jpg
# ./train/dogs/dog.559.jpg
# ./train/dogs/dog.652.jpg
# ./train/dogs/dog.939.jpg
# ./train/dogs/dog.934.jpg
# ./train/dogs/dog.730.jpg
# ./train/dogs/dog.29.jpg
# ./train/dogs/dog.826.jpg
# ./train/cats/cat.686.jpg
# ./train/cats/cat.501.jpg
# ./train/cats/cat.195.jpg
# ./train/cats/cat.885.jpg
# ./train/cats/cat.196.jpg
# ./train/cats/cat.817.jpg
# ./train/cats/cat.823.jpg
# ./train/cats/cat.199.jpg
# ./train/cats/cat.580.jpg
# ./train/cats/cat.947.jpg
# ./train/cats/cat.698.jpg
# ./train/cats/cat.615.jpg
# ./train/cats/cat.576.jpg
# ./train/cats/cat.697.jpg
# ./train/cats/cat.894.jpg
# ./train/cats/cat.409.jpg
# ./train/cats/cat.620.jpg
# ./train/cats/cat.730.jpg
# ./train/cats/cat.232.jpg
# ./train/cats/cat.578.jpg
# ./train/cats/cat.926.jpg
# ./train/cats/cat.760.jpg
# ./train/cats/cat.484.jpg
# ./train/cats/cat.57.jpg
# ./train/cats/cat.875.jpg
# ./train/cats/cat.703.jpg
# ./train/cats/cat.923.jpg
# ./train/cats/cat.452.jpg
# ./train/cats/cat.745.jpg
# ./train/cats/cat.311.jpg
# ./train/cats/cat.608.jpg
# ./train/cats/cat.554.jpg
# ./train/cats/cat.147.jpg
# ./train/cats/cat.808.jpg
# ./train/cats/cat.259.jpg
# ./train/cats/cat.848.jpg
# ./train/cats/cat.495.jpg
# ./train/cats/cat.161.jpg
# ./train/cats/cat.516.jpg
# /content

# %% [markdown]
# The following is from [Blog script 1](https://gist.github.com/fchollet/0830affa1f7f19fd47b06d4cf89ed44d)

# %% [markdown]
# # Utility routines
# Based on:  https://www.learnopencv.com/keras-tutorial-fine-tuning-using-pre-trained-models/

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

def plot_training(history):
  """
  Plot training and validation statistics
  - accuracy vs epoch number
  - loss     vs epoch number

  From https://www.learnopencv.com/keras-tutorial-fine-tuning-using-pre-trained-models/
  """

  # Accuracy
  acc = history.history['acc']
  val_acc = history.history['val_acc']

  # Loss
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'b', label='Training acc')
  plt.plot(epochs, val_acc, 'r', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %%
import re
import IPython

def trainModel(model, train_data_dir, validation_data_dir):
  # compile the model with a SGD/momentum optimizer
  # and a very slow learning rate.
  model.compile(loss='binary_crossentropy',
                #optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
                metrics=['acc'])

  # prepare data augmentation configuration
  train_datagen = ImageDataGenerator(
      rescale=1. / 255,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True)

  test_datagen = ImageDataGenerator(rescale=1. / 255)

  train_generator = train_datagen.flow_from_directory(
      train_data_dir,
      target_size=(img_height, img_width),
      batch_size=batch_size,
      class_mode='binary')

  validation_generator = test_datagen.flow_from_directory(
      validation_data_dir,
      target_size=(img_height, img_width),
      batch_size=batch_size,
      class_mode='binary')

  es_callback = EarlyStopping(monitor='val_loss', min_delta=.005, patience=2, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

  callbacks = [ es_callback,
                    # ModelCheckpoint(filepath=modelName + ".ckpt", monitor='acc', save_best_only=True)
                ]
  # fine-tune the model
  history = model.fit_generator(
      train_generator,
      # samples_per_epoch=nb_train_samples,
      steps_per_epoch=nb_train_samples // batch_size,
      epochs=epochs,
      validation_data=validation_generator,
      validation_steps=nb_validation_samples // batch_size,
      callbacks=callbacks
      )


  return history

def createTransferModel(base_model, last_base_layer_name, down_conv_features=32):
  model = Sequential()

  # Find the last layer
  layer_names = [ l.name for l in base_model.layers ]
  last_base_layer_idx = layer_names.index(last_base_layer_name)

  print("Last layer {ll:s} is index {i:d}".format(ll=last_base_layer_name, i=last_base_layer_idx))
  for i, layer in enumerate(base_model.layers[:last_base_layer_idx+1]):
    model.add(layer)
    layer.trainable=False

  # Add down sampling
  model.add( Conv2D(down_conv_features, kernel_size=(1, 1), activation='relu') )

  # Add head
  model.add(Flatten())
  model.add(Dense(32, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(1, activation='sigmoid'))


  return model

def plotModel(model, modelName):
  plotFile = modelName + ".png"
  plot_model(model, plotFile, show_shapes=True)

  return plotFile

# %% [markdown]
# # Problem description
# - Binary classification problem, with small quantity of training data
#
# - Cats and Dogs dataset:
#   - a *small* number of examples
#   - two classes: Cats, Dogs
#
# Plan
# 1. Create and train own model
# 1. Transfer Learning
#   - use the prefix of a pre-trained model
#   - add own suffix

# %%
'''This script goes along the blog post
"Building powerful image classification models using very little data"
from blog.keras.io.
It uses data that can be downloaded at:
https://www.kaggle.com/c/dogs-vs-cats/data
In our setup, we:
- created a data/ folder
- created train/ and validation/ subfolders inside data/
- created cats/ and dogs/ subfolders inside train/ and validation/
- put the cat pictures index 0-999 in data/train/cats
- put the cat pictures index 1000-1400 in data/validation/cats
- put the dogs pictures index 12500-13499 in data/train/dogs
- put the dog pictures index 13500-13900 in data/validation/dogs
So that we have 1000 training examples for each class, and 400 validation examples for each class.
In summary, this is our directory structure:
```
data/
    train/
        dogs/
            dog001.jpg
            dog002.jpg
            ...
        cats/
            cat001.jpg
            cat002.jpg
            ...
    validation/
        dogs/
            dog001.jpg
            dog002.jpg
            ...
        cats/
            cat001.jpg
            cat002.jpg
            ...
```
'''

# dimensions of our images.
img_width, img_height = 150, 150
image_size = 150
IMG_SHAPE = (image_size, image_size, 3)

train_data_dir = 'data/train'
validation_data_dir = 'data/validation'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16


def createFirstModel():
  if tf.keras.backend.image_data_format() == 'channels_first':
      input_shape = (3, img_width, img_height)
  else:
      input_shape = (img_width, img_height, 3)

  model = Sequential()
  model.add(Conv2D(32, (3, 3), padding="same", input_shape=input_shape))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(32, (3, 3), padding="same"))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(64, (3, 3), padding="same"))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Flatten())
  model.add(Dense(64))
  model.add(Activation('relu'))
  model.add(Dropout(0.5))
  model.add(Dense(1))
  model.add(Activation('sigmoid'))

  return model

# %% [markdown]
# # Create own model
# - multiple Conv2D/Pooling blocks

# %%
first_model = createFirstModel()
plotFile = plotModel(first_model, "first_model")
IPython.display.Image( plotFile)

# %%
first_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  activation (Activation)     (None, 150, 150, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 75, 75, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 32)        9248
#
#  activation_1 (Activation)   (None, 75, 75, 32)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 37, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 64)        18496
#
#  activation_2 (Activation)   (None, 37, 37, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 18, 18, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 20736)             0
#
#  dense (Dense)               (None, 64)                1327168
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_4 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1355873 (5.17 MB)
# Trainable params: 1355873 (5.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
first_history = trainModel(first_model, train_data_dir, validation_data_dir  )
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/50
# <ipython-input-7-3bed2bd7014a>:38: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 125/125 [==============================] - 16s 120ms/step - loss: 0.6926 - acc: 0.5500 - val_loss: 0.6738 - val_acc: 0.5487
# Epoch 2/50
# 125/125 [==============================] - 15s 119ms/step - loss: 0.6674 - acc: 0.6200 - val_loss: 0.7360 - val_acc: 0.5462
# Epoch 3/50
# 125/125 [==============================] - 15s 121ms/step - loss: 0.6371 - acc: 0.6325 - val_loss: 0.6293 - val_acc: 0.6112
# Epoch 4/50
# 125/125 [==============================] - 15s 119ms/step - loss: 0.6172 - acc: 0.6710 - val_loss: 0.6059 - val_acc: 0.6500
# Epoch 5/50
# 125/125 [==============================] - 15s 119ms/step - loss: 0.5978 - acc: 0.6855 - val_loss: 0.5978 - val_acc: 0.6687
# Epoch 6/50
# 125/125 [==============================] - 15s 119ms/step - loss: 0.5938 - acc: 0.6935 - val_loss: 0.5653 - val_acc: 0.7312
# Epoch 7/50
# 125/125 [==============================] - 15s 119ms/step - loss: 0.5750 - acc: 0.6955 - val_loss: 0.5346 - val_acc: 0.7412
# Epoch 8/50
# 125/125 [==============================] - 15s 118ms/step - loss: 0.5465 - acc: 0.7275 - val_loss: 0.6136 - val_acc: 0.6762
# Epoch 9/50
# 125/125 [==============================] - 15s 118ms/step - loss: 0.5421 - acc: 0.7340 - val_loss: 0.5344 - val_acc: 0.7387

# %%
first_model.save_weights('first_try.h5')

# %%
plot_training(first_history)

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import load_img

def show_errors(model, data_generator, data_dir, start=0, end=None):
  """
  Show misclassified images

  Adapted from: https://www.learnopencv.com/keras-tutorial-fine-tuning-using-pre-trained-models/

  data_generator generates images to classify
  - n.b., shuffle=False should be set when constructing this generator
  --- this is b/c when we ask the generator for .filenames and .classes  it is deterministic
  ---- the .classes form the "ground truth" against which predictions are evaluated so the order of examples must be deterministic
  Parameters
  -----------
  model: model for prediction
  data_generator: generator for data
  data_dir: the directory from which the generator obtains its data
  start, end: Integers.  Indices for first and last error (first error is 0)
  """

  # Get the filenames from the generator
  fnames = data_generator.filenames

  # Get the ground truth from generator
  ground_truth = data_generator.classes

  # Get the label to class mapping from the generator
  # i.e., { "class 0": 0, "class 1": 1, ... }
  label2index = xvalidation_generator.class_indices

  # Getting the mapping from class index to class label
  idx2label = dict((v,k) for k,v in label2index.items())

  # Get the predictions from the model using the generator
  predictions = model.predict_generator(data_generator, steps=data_generator.samples/data_generator.batch_size,verbose=1)

  # Handle special case where prediction is binary, not categorical
  # convert it into 2 categories
  if predictions.shape[-1] == 1:
    predictions = np.c_[ 1-predictions, predictions]

  predicted_classes = np.argmax(predictions,axis=1)

  # errors: list of indices where prediction is wrong
  errors = np.where(predicted_classes != ground_truth)[0]
  print("No of errors = {}/{}".format(len(errors),data_generator.samples))

  if end is None:
    end = len(errors)

  # Show the errors
  for i in range(start, end):
      pred_class = np.argmax(predictions[errors[i]])
      pred_label = idx2label[pred_class]

      title = 'Original label:{}, Prediction :{}, confidence : {:.3f}'.format(
          fnames[errors[i]].split('/')[0],
          pred_label,
          predictions[errors[i]][pred_class])

      original = load_img('{}/{}'.format(data_dir,fnames[errors[i]]))
      plt.figure(figsize=[7,7])
      plt.axis('off')
      plt.title(title)
      plt.imshow(original)
      plt.show()

# %%
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Need validation set to NOT be shuffled
#- n.b., shuffle=False should be set when constructing this generator
#  --- this is b/c when we ask the generator for .filenames and .classes  it is deterministic
#  ---- the .classes form the "ground truth" against which predictions are evaluated so the order of examples must be deterministic
xvalidation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

show_errors(first_model, xvalidation_generator, validation_data_dir, start=1, end=10)
# Out:
# Found 800 images belonging to 2 classes.
# <ipython-input-14-25b8f1a6f66a>:36: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(data_generator, steps=data_generator.samples/data_generator.batch_size,verbose=1)
# 50/50 [==============================] - 2s 30ms/step
# No of errors = 305/800

# %% [markdown]
# # Load a pre-trained VGG16 model

# %%
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                     include_top=False,
                                     weights='imagenet')

plotFile = plotModel(base_model, "vgg16_model")
IPython.display.Image( plotFile)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Transfer Learning: Graft a new head onto VGG 16

# %%
transf_model = createTransferModel(base_model,  base_model.layers[-1].name)
transf_model.summary()
# Out:
# Last layer block5_pool is index 18
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 32)          16416
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 32)                16416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 14747553 (56.26 MB)
# Trainable params: 32865 (128.38 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
transf_history = trainModel(transf_model, train_data_dir, validation_data_dir)
plot_training(transf_history)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/50
# <ipython-input-7-3bed2bd7014a>:38: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 125/125 [==============================] - 21s 144ms/step - loss: 0.4980 - acc: 0.7535 - val_loss: 0.3098 - val_acc: 0.8637
# Epoch 2/50
# 125/125 [==============================] - 18s 144ms/step - loss: 0.3619 - acc: 0.8450 - val_loss: 0.2903 - val_acc: 0.8838
# Epoch 3/50
# 125/125 [==============================] - 17s 135ms/step - loss: 0.3274 - acc: 0.8615 - val_loss: 0.2464 - val_acc: 0.9025
# Epoch 4/50
# 125/125 [==============================] - 18s 144ms/step - loss: 0.2819 - acc: 0.8795 - val_loss: 0.2266 - val_acc: 0.9062
# Epoch 5/50
# 125/125 [==============================] - 18s 142ms/step - loss: 0.2544 - acc: 0.9030 - val_loss: 0.2343 - val_acc: 0.9075
# Epoch 6/50
# 125/125 [==============================] - 17s 136ms/step - loss: 0.2401 - acc: 0.9080 - val_loss: 0.2397 - val_acc: 0.9062

# %% [markdown]
# # Transfer Learning: Graft a new suffix onto a VGG16 prefix
# - Do we do better or worse by elminating later layers of VGG 16 (perhaps too specialized ?)

# %%
transf_model = createTransferModel(base_model, 'block4_pool')
# Out:
# Last layer block4_pool is index 14

# %%
transf_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  conv2d_4 (Conv2D)           (None, 9, 9, 32)          16416
#
#  flatten_2 (Flatten)         (None, 2592)              0
#
#  dense_4 (Dense)             (None, 32)                82976
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7734689 (29.51 MB)
# Trainable params: 99425 (388.38 KB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
transf_history = trainModel(transf_model, train_data_dir, validation_data_dir)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/50
# <ipython-input-7-3bed2bd7014a>:38: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 125/125 [==============================] - 19s 139ms/step - loss: 0.6324 - acc: 0.6705 - val_loss: 0.3945 - val_acc: 0.8275
# Epoch 2/50
# 125/125 [==============================] - 17s 139ms/step - loss: 0.4134 - acc: 0.8170 - val_loss: 0.3222 - val_acc: 0.8612
# Epoch 3/50
# 125/125 [==============================] - 17s 133ms/step - loss: 0.3337 - acc: 0.8615 - val_loss: 0.3151 - val_acc: 0.8813
# Epoch 4/50
# 125/125 [==============================] - 17s 135ms/step - loss: 0.2638 - acc: 0.8935 - val_loss: 0.3306 - val_acc: 0.8537
# Epoch 5/50
# 125/125 [==============================] - 16s 131ms/step - loss: 0.2296 - acc: 0.9145 - val_loss: 0.2422 - val_acc: 0.9100
# Epoch 6/50
# 125/125 [==============================] - 16s 130ms/step - loss: 0.2124 - acc: 0.9180 - val_loss: 0.1926 - val_acc: 0.9287
# Epoch 7/50
# 125/125 [==============================] - 17s 140ms/step - loss: 0.1941 - acc: 0.9270 - val_loss: 0.2110 - val_acc: 0.9312
# Epoch 8/50
# 125/125 [==============================] - 17s 132ms/step - loss: 0.1648 - acc: 0.9325 - val_loss: 0.2095 - val_acc: 0.9275

# %%
plot_training(transf_history)

# %% [markdown]
# # Transfer Learning: Graft a new head onto *an even shorter* prefix of VGG 16.
# - Can we still learn ?

# %%
transf_model = createTransferModel(base_model, 'block3_pool')
transf_model.summary()
# Out:
# Last layer block3_pool is index 10
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  conv2d_5 (Conv2D)           (None, 18, 18, 32)        8224
#
#  flatten_3 (Flatten)         (None, 10368)             0
#
#  dense_6 (Dense)             (None, 32)                331808
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2075553 (7.92 MB)
# Trainable params: 340065 (1.30 MB)
# Non-trainable params: 1735488 (6.62 MB)
# _________________________________________________________________

# %%
transf_history = trainModel(transf_model, train_data_dir, validation_data_dir)
plot_training(transf_history)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/50
# <ipython-input-7-3bed2bd7014a>:38: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 125/125 [==============================] - 17s 127ms/step - loss: 2.9498 - acc: 0.5195 - val_loss: 0.6872 - val_acc: 0.5775
# Epoch 2/50
# 125/125 [==============================] - 17s 136ms/step - loss: 0.6942 - acc: 0.6050 - val_loss: 0.6289 - val_acc: 0.7925
# Epoch 3/50
# 125/125 [==============================] - 16s 128ms/step - loss: 0.6555 - acc: 0.6120 - val_loss: 0.5778 - val_acc: 0.7937
# Epoch 4/50
# 125/125 [==============================] - 16s 126ms/step - loss: 0.6638 - acc: 0.6585 - val_loss: 0.6925 - val_acc: 0.7450
# Epoch 5/50
# 125/125 [==============================] - 17s 134ms/step - loss: 0.5853 - acc: 0.6735 - val_loss: 0.4891 - val_acc: 0.7663
# Epoch 6/50
# 125/125 [==============================] - 16s 129ms/step - loss: 0.5784 - acc: 0.6955 - val_loss: 0.4531 - val_acc: 0.8150
# Epoch 7/50
# 125/125 [==============================] - 16s 126ms/step - loss: 0.5226 - acc: 0.7345 - val_loss: 0.4688 - val_acc: 0.7862
# Epoch 8/50
# 125/125 [==============================] - 17s 138ms/step - loss: 0.4829 - acc: 0.7675 - val_loss: 0.4002 - val_acc: 0.8500
# Epoch 9/50
# 125/125 [==============================] - 16s 128ms/step - loss: 0.4722 - acc: 0.7680 - val_loss: 0.3771 - val_acc: 0.8537
# Epoch 10/50
# 125/125 [==============================] - 16s 128ms/step - loss: 0.4748 - acc: 0.7815 - val_loss: 0.3769 - val_acc: 0.8562
# Epoch 11/50
# 125/125 [==============================] - 16s 126ms/step - loss: 0.4610 - acc: 0.8040 - val_loss: 0.4648 - val_acc: 0.8238
